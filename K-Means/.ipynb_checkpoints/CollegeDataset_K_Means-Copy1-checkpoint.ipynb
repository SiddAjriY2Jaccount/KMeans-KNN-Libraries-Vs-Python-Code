# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random as rd
import seaborn as sns

# %%
dataset = pd.read_csv('College.csv')
dataset.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15

# %%
dataset['Enrollment_Rate'] = (dataset['Enroll']/dataset['Accept'])*100.0
dataset.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate  Enrollment_Rate
# 0   70        78       18.1           12    7041         60        58.522727
# 1   29        30       12.2           16   10527         56        26.611227
# 2   53        66       12.9           30    8735         54        30.628988
# 3   92        97        7.7           37   19016         59        39.255014
# 4   76        72       11.9            2   10922         15        37.671233

# %%
dataset['Acceptance Rate'] = (dataset['Accept']/dataset['Apps'])*100.0
dataset.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate       ...         Books  \
# 0         52         2885          537      7440       ...           450
# 1         29         2683         1227     12280       ...           750
# 2         50         1036           99     11250       ...           400
# 3         89          510           63     12960       ...           450
# 4         44          249          869      7560       ...           800
#
#    Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate  \
# 0      2200   70        78       18.1           12    7041         60
# 1      1500   29        30       12.2           16   10527         56
# 2      1165   53        66       12.9           30    8735         54
# 3       875   92        97        7.7           37   19016         59
# 4      1500   76        72       11.9            2   10922         15
#
#    Enrollment_Rate  Acceptance Rate
# 0        58.522727        74.216867
# 1        26.611227        88.014639
# 2        30.628988        76.820728
# 3        39.255014        83.693046
# 4        37.671233        75.647668
#
# [5 rows x 21 columns]

# %%
dataset[dataset['Enrollment_Rate'] == 100]
# Out:
#                         Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 77  California Lutheran University     Yes   563     247     247         23
#
#     Top25perc  F.Undergrad  P.Undergrad  Outstate       ...         Books  \
# 77         52         1427          432     12950       ...           612
#
#     Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate  \
# 77       576   72        74       12.4           17    8985         60
#
#     Enrollment_Rate  Acceptance Rate
# 77            100.0        43.872114
#
# [1 rows x 21 columns]

# %%
dataset.shape
# Out:
# (777, 21)

# %%
sns.set_style('whitegrid')
sns.lmplot('Enrollment_Rate','Expend',data=dataset, hue='Private',
           palette='coolwarm',height=6,aspect=1,fit_reg=False)

# %%
X = dataset.iloc[:, [17, 19]].values #Choosing Room.Board and Grad.Rate as Atrributes
X
# Out:
# array([[7.04100000e+03, 5.85227273e+01],
#        [1.05270000e+04, 2.66112266e+01],
#        [8.73500000e+03, 3.06289881e+01],
#        ...,
#        [8.32300000e+03, 3.62924282e+01],
#        [4.03860000e+04, 5.36893600e+01],
#        [4.50900000e+03, 3.72506739e+01]])

# %%
print(X.shape)

m = X.shape[0] #number of training examples
n = X.shape[1] #number of features. Here n will be 2, naturally

print("m,n",m,n)

epochs = 100 #max no. of iterations
# Out:
# (777, 2)
# m,n 777 2

# %%
K = 2  # number of clusters, for now, change it later

# %%
Centroids = np.array([]).reshape(n,0) #Centroids is a n x K dimensional matrix, where each column will be a centroid for one cluster

# %%
print(np.array(Centroids))
# Out:
# []

# %%
for i in range(K):
    rand = rd.randint(0,m-1)
    Centroids = np.c_[Centroids,X[rand]]

Centroids
# Out:
# array([[ 7846.        , 10368.        ],
#        [   42.24447869,    40.45275591]])

# %%
Output={} #Dict with key as Cluster no. and Values as each data point in the cluster

# %%
'''
EuclidianDistance = np.array([]).reshape(m,0)
for k in range(K):
    tempDist = np.sum((X-Centroids[:,k])**2,axis=1)
    EuclidianDistance = np.c_[EuclidianDistance,tempDist]
C = np.argmin(EuclidianDistance,axis=1)+1

C
'''
# Out:
# '\nEuclidianDistance = np.array([]).reshape(m,0)\nfor k in range(K):\n    tempDist = np.sum((X-Centroids[:,k])**2,axis=1)\n    EuclidianDistance = np.c_[EuclidianDistance,tempDist]\nC = np.argmin(EuclidianDistance,axis=1)+1\n\nC\n'

# %%
for i in range(epochs):
     #step 2.a
      EuclidianDistance = np.array([]).reshape(m,0)
      for k in range(K):
          tempDist=np.sum((X-Centroids[:,k])**2,axis=1)
          EuclidianDistance=np.c_[EuclidianDistance,tempDist]
      C=np.argmin(EuclidianDistance,axis=1)+1
     #step 2(b)
      Y={}
      for k in range(K):
          Y[k+1]=np.array([]).reshape(2,0)
      for i in range(m):
          Y[C[i]]=np.c_[Y[C[i]],X[i]]
     
      for k in range(K):
          Y[k+1]=Y[k+1].T
    
      for k in range(K):
          Centroids[:,k]=np.mean(Y[k+1],axis=0)
      Output=Y
    
Output
# Out:
# {1: array([[ 7041.        ,    58.52272727],
#         [10527.        ,    26.61122661],
#         [ 8735.        ,    30.62898815],
#         ...,
#         [ 9189.        ,    38.50415512],
#         [ 8323.        ,    36.2924282 ],
#         [ 4509.        ,    37.25067385]]),
#  2: array([[1.90160000e+04, 3.92550143e+01],
#         [1.42310000e+04, 3.36363636e+01],
#         [1.80340000e+04, 2.65850945e+01],
#         [1.47030000e+04, 3.30583058e+01],
#         [1.69200000e+04, 2.38634146e+01],
#         [1.54110000e+04, 3.08411215e+01],
#         [1.63520000e+04, 7.44444444e+01],
#         [1.39190000e+04, 3.89602521e+01],
#         [1.59340000e+04, 2.29976798e+01],
#         [3.68540000e+04, 3.07435812e+01],
#         [1.38890000e+04, 4.33639474e+01],
#         [1.47370000e+04, 4.10027162e+01],
#         [1.38830000e+04, 4.73197136e+01],
#         [1.75000000e+04, 3.05050130e+01],
#         [1.48470000e+04, 3.78129830e+01],
#         [1.61220000e+04, 5.50883227e+01],
#         [1.58930000e+04, 5.56558062e+01],
#         [1.39360000e+04, 5.15135135e+01],
#         [2.57650000e+04, 4.70948012e+01],
#         [1.37890000e+04, 3.92135360e+01],
#         [2.60370000e+04, 2.26082212e+01],
#         [1.70070000e+04, 2.91480348e+01],
#         [1.87840000e+04, 3.37474120e+01],
#         [1.65270000e+04, 4.75871886e+01],
#         [2.38500000e+04, 3.19616205e+01],
#         [1.70890000e+04, 3.47895578e+01],
#         [1.49040000e+04, 4.10914928e+01],
#         [4.17660000e+04, 3.77508361e+01],
#         [1.57360000e+04, 3.87773723e+01],
#         [4.57020000e+04, 2.38448374e+01],
#         [2.14090000e+04, 4.63570857e+01],
#         [1.39350000e+04, 5.41666667e+01],
#         [1.78580000e+04, 3.59586317e+01],
#         [1.62620000e+04, 3.60871769e+01],
#         [2.27040000e+04, 3.03714494e+01],
#         [2.20140000e+04, 4.22489960e+01],
#         [4.03860000e+04, 5.36893600e+01]])}

# %%
Centroids
# Out:
# array([[ 8114.00149031, 19447.71698113],
#        [   42.0407412 ,    35.88871796]])

# %%
color=['red','blue','green','cyan','magenta']
labels=['Public','Private','cluster-3','cluster-4','cluster-5']
for k in range(K):
    plt.scatter(Output[k+1][:,0],Output[k+1][:,1],c=color[k],label=labels[k])
plt.scatter(Centroids[0,:],Centroids[1,:],s=100,c='yellow',label='Centroids')
plt.xlabel('Enrollment_Rate')
plt.ylabel('Expend')
plt.legend()
plt.show()
#Output[k+1][:,0]
#Output[k+1][:,1]

# %%
i2=[]
for i1 in Output[1]:
    i2.append(list(i1))


#i2 is a list of of all the data points clustered as Public

# %%
dataset['Class_label'] = np.nan
dataset
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# 11                         Allegheny College     Yes   2652    1900     484
# 12   Allentown Coll. of St. Francis de Sales     Yes   1179     780     290
# 13                              Alma College     Yes   1267    1080     385
# 14                           Alverno College     Yes    494     313     157
# 15            American International College     Yes   1420    1093     220
# 16                           Amherst College     Yes   4302     992     418
# 17                       Anderson University     Yes   1216     908     423
# 18                        Andrews University     Yes   1130     704     322
# 19                   Angelo State University      No   3540    2001    1016
# 20                        Antioch University     Yes    713     661     252
# 21              Appalachian State University      No   7313    4664    1910
# 22                           Aquinas College     Yes    619     516     219
# 23      Arizona State University Main campus      No  12809   10308    3761
# 24           Arkansas College (Lyon College)     Yes    708     334     166
# 25                  Arkansas Tech University      No   1734    1729     951
# 26                        Assumption College     Yes   2135    1700     491
# 27             Auburn University-Main Campus      No   7548    6791    3070
# 28                          Augsburg College     Yes    662     513     257
# 29                      Augustana College IL     Yes   1879    1658     497
# ..                                       ...     ...    ...     ...     ...
# 747                  Westfield State College      No   3100    2150     825
# 748                   Westminster College MO     Yes    662     553     184
# 749                      Westminster College     Yes    996     866     377
# 750    Westminster College of Salt Lake City     Yes    917     720     213
# 751                         Westmont College      No    950     713     351
# 752                       Wheaton College IL     Yes   1432     920     548
# 753                   Westminster College PA     Yes   1738    1373     417
# 754                  Wheeling Jesuit College     Yes    903     755     213
# 755                          Whitman College     Yes   1861     998     359
# 756                         Whittier College     Yes   1681    1069     344
# 757                        Whitworth College     Yes   1121     926     372
# 758                       Widener University     Yes   2139    1492     502
# 759                        Wilkes University     Yes   1631    1431     434
# 760                    Willamette University     Yes   1658    1327     395
# 761                   William Jewell College     Yes    663     547     315
# 762                 William Woods University     Yes    469     435     227
# 763                         Williams College     Yes   4186    1245     526
# 764                           Wilson College     Yes    167     130      46
# 765                          Wingate College     Yes   1239    1017     383
# 766                  Winona State University      No   3325    2047    1301
# 767                      Winthrop University      No   2320    1805     769
# 768               Wisconsin Lutheran College     Yes    152     128      75
# 769                    Wittenberg University     Yes   1979    1739     575
# 770                          Wofford College     Yes   1501     935     273
# 771          Worcester Polytechnic Institute     Yes   2768    2314     682
# 772                  Worcester State College      No   2197    1515     543
# 773                        Xavier University     Yes   1959    1805     695
# 774           Xavier University of Louisiana     Yes   2097    1915     695
# 775                          Yale University     Yes  10705    2453    1317
# 776             York College of Pennsylvania     Yes   2989    1855     691
#
#      Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate     ...       \
# 0           23         52         2885          537      7440     ...
# 1           16         29         2683         1227     12280     ...
# 2           22         50         1036           99     11250     ...
# 3           60         89          510           63     12960     ...
# 4           16         44          249          869      7560     ...
# 5           38         62          678           41     13500     ...
# 6           17         45          416          230     13290     ...
# 7           37         68         1594           32     13868     ...
# 8           30         63          973          306     15595     ...
# 9           21         44          799           78     10468     ...
# 10          37         75         1830          110     16548     ...
# 11          44         77         1707           44     17080     ...
# 12          38         64         1130          638      9690     ...
# 13          44         73         1306           28     12572     ...
# 14          23         46         1317         1235      8352     ...
# 15           9         22         1018          287      8700     ...
# 16          83         96         1593            5     19760     ...
# 17          19         40         1819          281     10100     ...
# 18          14         23         1586          326      9996     ...
# 19          24         54         4190         1512      5130     ...
# 20          25         44          712           23     15476     ...
# 21          20         63         9940         1035      6806     ...
# 22          20         51         1251          767     11208     ...
# 23          24         49        22593         7585      7434     ...
# 24          46         74          530          182      8644     ...
# 25          12         52         3602          939      3460     ...
# 26          23         59         1708          689     12000     ...
# 27          25         57        16262         1716      6300     ...
# 28          12         30         2074          726     11902     ...
# 29          36         69         1950           38     13353     ...
# ..         ...        ...          ...          ...       ...     ...
# 747          3         20         3234          941      5542     ...
# 748         20         43          665           37     10720     ...
# 749         29         58         1411           72     12065     ...
# 750         21         60          979          743      8820     ...
# 751         42         72         1276            9     14320     ...
# 752         56         84         2200           56     11480     ...
# 753         21         55         1335           30     18460     ...
# 754         15         49          971          305     10500     ...
# 755         45         77         1220           46     16670     ...
# 756         35         63         1235           30     16249     ...
# 757         43         70         1270          160     12660     ...
# 758         24         64         2186         2171     12350     ...
# 759         15         36         1803          603     11150     ...
# 760         49         80         1595          159     14800     ...
# 761         32         67         1279           75     10060     ...
# 762         17         39          851          120     10535     ...
# 763         81         96         1988           29     19629     ...
# 764         16         50          199          676     11428     ...
# 765         10         34         1207          157      7820     ...
# 766         20         45         5800          872      4200     ...
# 767         24         61         3395          670      6400     ...
# 768         17         41          282           22      9100     ...
# 769         42         68         1980          144     15948     ...
# 770         51         83         1059           34     12680     ...
# 771         49         86         2802           86     15884     ...
# 772          4         26         3089         2029      6797     ...
# 773         24         47         2849         1107     11520     ...
# 774         34         61         2793          166      6900     ...
# 775         95         99         5217           83     19840     ...
# 776         28         63         2988         1726      4990     ...
#
#      Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate  \
# 0        2200   70        78       18.1           12    7041         60
# 1        1500   29        30       12.2           16   10527         56
# 2        1165   53        66       12.9           30    8735         54
# 3         875   92        97        7.7           37   19016         59
# 4        1500   76        72       11.9            2   10922         15
# 5         675   67        73        9.4           11    9727         55
# 6        1500   90        93       11.5           26    8861         63
# 7         850   89       100       13.7           37   11487         73
# 8         500   79        84       11.3           23   11644         80
# 9        1800   40        41       11.5           15    8991         52
# 10        600   82        88       11.3           31   10932         73
# 11        600   73        91        9.9           41   11711         76
# 12       1000   60        84       13.3           21    7940         74
# 13        400   79        87       15.3           32    9305         68
# 14       2449   36        69       11.1           26    8127         55
# 15       1400   78        84       14.7           19    7355         69
# 16       1598   93        98        8.4           63   21424        100
# 17       1100   48        61       12.1           14    7994         59
# 18       1320   62        66       11.5           18   10908         46
# 19       2000   60        62       23.1            5    4010         34
# 20       1100   69        82       11.3           35   42926         48
# 21       2000   83        96       18.3           14    5854         70
# 22       1615   55        65       12.7           25    6584         65
# 23       2100   88        93       18.9            5    4602         48
# 24        800   79        88       12.6           24   14579         54
# 25       1000   57        60       19.6            5    4739         48
# 26        500   93        93       13.8           30    7100         88
# 27       1908   85        91       16.7           18    6642         69
# 28        950   65        65       12.8           31    7836         58
# 29        821   78        83       12.7           40    9220         71
# ..        ...  ...       ...        ...          ...     ...        ...
# 747      1300   75        79       15.7           20    4222         65
# 748      1650   66        70       12.5           20    7925         62
# 749       685   62        78       12.5           41    8596         80
# 750      2025   68        83       10.5           34    7170         50
# 751      1410   77        77       14.9           17    8837         87
# 752      1400   81        83       12.7           40   11916         85
# 753       850   92        96       13.2           41   22704         71
# 754       600   66        71       14.1           27    7494         72
# 755       800   80        83       10.5           51   13198         72
# 756      1998   84        92       13.6           29   11778         52
# 757      2424   80        80       16.9           20    8328         80
# 758      1350   88        86       12.6           19    9603         63
# 759      1260   78        92       13.3           24    8543         67
# 760       790   91        94       13.3           37   10779         68
# 761      2600   74        80       11.2           19    7885         59
# 762      3700   39        66       12.9           16    7438         52
# 763      1200   94        99        9.0           64   22014         99
# 764       475   67        76        8.3           43   10291         67
# 765      1550   69        81       13.9            8    7264         91
# 766      1200   53        60       20.2           18    5318         58
# 767      2150   71        80       12.8           26    6729         59
# 768      1400   48        48        8.5           26    8960         50
# 769       800   82        95       12.8           29   10414         78
# 770      1440   91        92       15.3           42    7875         75
# 771       730   92        94       15.2           34   10774         82
# 772      1200   60        60       21.0           14    4469         40
# 773      1250   73        75       13.3           31    9189         83
# 774       781   67        75       14.4           20    8323         49
# 775      2115   96        96        5.8           49   40386         99
# 776      1250   75        75       18.1           28    4509         99
#
#      Enrollment_Rate  Acceptance Rate  Class_label
# 0          58.522727        74.216867          NaN
# 1          26.611227        88.014639          NaN
# 2          30.628988        76.820728          NaN
# 3          39.255014        83.693046          NaN
# 4          37.671233        75.647668          NaN
# 5          32.985386        81.601363          NaN
# 6          30.294118        96.317280          NaN
# 7          28.430233        90.573986          NaN
# 8          27.056019        80.828516          NaN
# 9          34.538153        85.567010          NaN
# 10         33.122807        82.274827          NaN
# 11         25.473684        71.644042          NaN
# 12         37.179487        66.157761          NaN
# 13         35.648148        85.240726          NaN
# 14         50.159744        63.360324          NaN
# 15         20.128088        76.971831          NaN
# 16         42.137097        23.059042          NaN
# 17         46.585903        74.671053          NaN
# 18         45.738636        62.300885          NaN
# 19         50.774613        56.525424          NaN
# 20         38.124054        92.706872          NaN
# 21         40.951973        63.776836          NaN
# 22         42.441860        83.360258          NaN
# 23         36.486224        80.474666          NaN
# 24         49.700599        47.175141          NaN
# 25         55.002892        99.711649          NaN
# 26         28.882353        79.625293          NaN
# 27         45.206891        89.970853          NaN
# 28         50.097466        77.492447          NaN
# 29         29.975875        88.238425          NaN
# ..               ...              ...          ...
# 747        38.372093        69.354839          NaN
# 748        33.273056        83.534743          NaN
# 749        43.533487        86.947791          NaN
# 750        29.583333        78.516903          NaN
# 751        49.228612        75.052632          NaN
# 752        59.565217        64.245810          NaN
# 753        30.371449        78.998849          NaN
# 754        28.211921        83.610188          NaN
# 755        35.971944        53.627082          NaN
# 756        32.179607        63.593099          NaN
# 757        40.172786        82.604817          NaN
# 758        33.646113        69.752221          NaN
# 759        30.328442        87.737584          NaN
# 760        29.766390        80.036188          NaN
# 761        57.586837        82.503771          NaN
# 762        52.183908        92.750533          NaN
# 763        42.248996        29.741997          NaN
# 764        35.384615        77.844311          NaN
# 765        37.659784        82.082324          NaN
# 766        63.556424        61.563910          NaN
# 767        42.603878        77.801724          NaN
# 768        58.593750        84.210526          NaN
# 769        33.064980        87.872663          NaN
# 770        29.197861        62.291805          NaN
# 771        29.472774        83.598266          NaN
# 772        35.841584        68.957670          NaN
# 773        38.504155        92.138846          NaN
# 774        36.292428        91.320935          NaN
# 775        53.689360        22.914526          NaN
# 776        37.250674        62.060890          NaN
#
# [777 rows x 22 columns]

# %%
no_of_rows, no_of_cols = dataset.shape
print(no_of_rows)
# Out:
# 777

# %%
for kk in i2:
    dataset.loc[(dataset['Expend']==kk[0])&(dataset['Enrollment_Rate']==kk[1]),'Class_label'] = 'No'

# %%
dataset
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# 11                         Allegheny College     Yes   2652    1900     484
# 12   Allentown Coll. of St. Francis de Sales     Yes   1179     780     290
# 13                              Alma College     Yes   1267    1080     385
# 14                           Alverno College     Yes    494     313     157
# 15            American International College     Yes   1420    1093     220
# 16                           Amherst College     Yes   4302     992     418
# 17                       Anderson University     Yes   1216     908     423
# 18                        Andrews University     Yes   1130     704     322
# 19                   Angelo State University      No   3540    2001    1016
# 20                        Antioch University     Yes    713     661     252
# 21              Appalachian State University      No   7313    4664    1910
# 22                           Aquinas College     Yes    619     516     219
# 23      Arizona State University Main campus      No  12809   10308    3761
# 24           Arkansas College (Lyon College)     Yes    708     334     166
# 25                  Arkansas Tech University      No   1734    1729     951
# 26                        Assumption College     Yes   2135    1700     491
# 27             Auburn University-Main Campus      No   7548    6791    3070
# 28                          Augsburg College     Yes    662     513     257
# 29                      Augustana College IL     Yes   1879    1658     497
# ..                                       ...     ...    ...     ...     ...
# 747                  Westfield State College      No   3100    2150     825
# 748                   Westminster College MO     Yes    662     553     184
# 749                      Westminster College     Yes    996     866     377
# 750    Westminster College of Salt Lake City     Yes    917     720     213
# 751                         Westmont College      No    950     713     351
# 752                       Wheaton College IL     Yes   1432     920     548
# 753                   Westminster College PA     Yes   1738    1373     417
# 754                  Wheeling Jesuit College     Yes    903     755     213
# 755                          Whitman College     Yes   1861     998     359
# 756                         Whittier College     Yes   1681    1069     344
# 757                        Whitworth College     Yes   1121     926     372
# 758                       Widener University     Yes   2139    1492     502
# 759                        Wilkes University     Yes   1631    1431     434
# 760                    Willamette University     Yes   1658    1327     395
# 761                   William Jewell College     Yes    663     547     315
# 762                 William Woods University     Yes    469     435     227
# 763                         Williams College     Yes   4186    1245     526
# 764                           Wilson College     Yes    167     130      46
# 765                          Wingate College     Yes   1239    1017     383
# 766                  Winona State University      No   3325    2047    1301
# 767                      Winthrop University      No   2320    1805     769
# 768               Wisconsin Lutheran College     Yes    152     128      75
# 769                    Wittenberg University     Yes   1979    1739     575
# 770                          Wofford College     Yes   1501     935     273
# 771          Worcester Polytechnic Institute     Yes   2768    2314     682
# 772                  Worcester State College      No   2197    1515     543
# 773                        Xavier University     Yes   1959    1805     695
# 774           Xavier University of Louisiana     Yes   2097    1915     695
# 775                          Yale University     Yes  10705    2453    1317
# 776             York College of Pennsylvania     Yes   2989    1855     691
#
#      Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate     ...       \
# 0           23         52         2885          537      7440     ...
# 1           16         29         2683         1227     12280     ...
# 2           22         50         1036           99     11250     ...
# 3           60         89          510           63     12960     ...
# 4           16         44          249          869      7560     ...
# 5           38         62          678           41     13500     ...
# 6           17         45          416          230     13290     ...
# 7           37         68         1594           32     13868     ...
# 8           30         63          973          306     15595     ...
# 9           21         44          799           78     10468     ...
# 10          37         75         1830          110     16548     ...
# 11          44         77         1707           44     17080     ...
# 12          38         64         1130          638      9690     ...
# 13          44         73         1306           28     12572     ...
# 14          23         46         1317         1235      8352     ...
# 15           9         22         1018          287      8700     ...
# 16          83         96         1593            5     19760     ...
# 17          19         40         1819          281     10100     ...
# 18          14         23         1586          326      9996     ...
# 19          24         54         4190         1512      5130     ...
# 20          25         44          712           23     15476     ...
# 21          20         63         9940         1035      6806     ...
# 22          20         51         1251          767     11208     ...
# 23          24         49        22593         7585      7434     ...
# 24          46         74          530          182      8644     ...
# 25          12         52         3602          939      3460     ...
# 26          23         59         1708          689     12000     ...
# 27          25         57        16262         1716      6300     ...
# 28          12         30         2074          726     11902     ...
# 29          36         69         1950           38     13353     ...
# ..         ...        ...          ...          ...       ...     ...
# 747          3         20         3234          941      5542     ...
# 748         20         43          665           37     10720     ...
# 749         29         58         1411           72     12065     ...
# 750         21         60          979          743      8820     ...
# 751         42         72         1276            9     14320     ...
# 752         56         84         2200           56     11480     ...
# 753         21         55         1335           30     18460     ...
# 754         15         49          971          305     10500     ...
# 755         45         77         1220           46     16670     ...
# 756         35         63         1235           30     16249     ...
# 757         43         70         1270          160     12660     ...
# 758         24         64         2186         2171     12350     ...
# 759         15         36         1803          603     11150     ...
# 760         49         80         1595          159     14800     ...
# 761         32         67         1279           75     10060     ...
# 762         17         39          851          120     10535     ...
# 763         81         96         1988           29     19629     ...
# 764         16         50          199          676     11428     ...
# 765         10         34         1207          157      7820     ...
# 766         20         45         5800          872      4200     ...
# 767         24         61         3395          670      6400     ...
# 768         17         41          282           22      9100     ...
# 769         42         68         1980          144     15948     ...
# 770         51         83         1059           34     12680     ...
# 771         49         86         2802           86     15884     ...
# 772          4         26         3089         2029      6797     ...
# 773         24         47         2849         1107     11520     ...
# 774         34         61         2793          166      6900     ...
# 775         95         99         5217           83     19840     ...
# 776         28         63         2988         1726      4990     ...
#
#      Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate  \
# 0        2200   70        78       18.1           12    7041         60
# 1        1500   29        30       12.2           16   10527         56
# 2        1165   53        66       12.9           30    8735         54
# 3         875   92        97        7.7           37   19016         59
# 4        1500   76        72       11.9            2   10922         15
# 5         675   67        73        9.4           11    9727         55
# 6        1500   90        93       11.5           26    8861         63
# 7         850   89       100       13.7           37   11487         73
# 8         500   79        84       11.3           23   11644         80
# 9        1800   40        41       11.5           15    8991         52
# 10        600   82        88       11.3           31   10932         73
# 11        600   73        91        9.9           41   11711         76
# 12       1000   60        84       13.3           21    7940         74
# 13        400   79        87       15.3           32    9305         68
# 14       2449   36        69       11.1           26    8127         55
# 15       1400   78        84       14.7           19    7355         69
# 16       1598   93        98        8.4           63   21424        100
# 753        30.371449        78.998849          NaN
# 754        28.211921        83.610188           No
# 755        35.971944        53.627082           No
# 756        32.179607        63.593099           No
# 757        40.172786        82.604817           No
# 758        33.646113        69.752221           No
# 759        30.328442        87.737584           No
# 760        29.766390        80.036188           No
# 761        57.586837        82.503771           No
# 762        52.183908        92.750533           No
# 763        42.248996        29.741997          NaN
# 764        35.384615        77.844311           No
# 765        37.659784        82.082324           No
# 766        63.556424        61.563910           No
# 767        42.603878        77.801724           No
# 768        58.593750        84.210526           No
# 769        33.064980        87.872663           No
# 770        29.197861        62.291805           No
# 771        29.472774        83.598266           No
# 772        35.841584        68.957670           No
# 773        38.504155        92.138846           No
# 774        36.292428        91.320935           No
# 775        53.689360        22.914526          NaN
# 776        37.250674        62.060890           No
#
# [777 rows x 22 columns]

# %%
i9=[]
for i1 in Output[2]:
    i9.append(list(i1))


#i9 is a list of of all the data points clustered as Private

# %%
for kk in i9:
    dataset.loc[(dataset['Expend']==kk[0])&(dataset['Enrollment_Rate']==kk[1]),'Class_label'] = 'Yes'

dataset
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# 11                         Allegheny College     Yes   2652    1900     484
# 12   Allentown Coll. of St. Francis de Sales     Yes   1179     780     290
# 13                              Alma College     Yes   1267    1080     385
# 14                           Alverno College     Yes    494     313     157
# 15            American International College     Yes   1420    1093     220
# 16                           Amherst College     Yes   4302     992     418
# 17                       Anderson University     Yes   1216     908     423
# 18                        Andrews University     Yes   1130     704     322
# 19                   Angelo State University      No   3540    2001    1016
# 20                        Antioch University     Yes    713     661     252
# 21              Appalachian State University      No   7313    4664    1910
# 22                           Aquinas College     Yes    619     516     219
# 23      Arizona State University Main campus      No  12809   10308    3761
# 24           Arkansas College (Lyon College)     Yes    708     334     166
# 25                  Arkansas Tech University      No   1734    1729     951
# 26                        Assumption College     Yes   2135    1700     491
# 27             Auburn University-Main Campus      No   7548    6791    3070
# 28                          Augsburg College     Yes    662     513     257
# 29                      Augustana College IL     Yes   1879    1658     497
# ..                                       ...     ...    ...     ...     ...
# 747                  Westfield State College      No   3100    2150     825
# 748                   Westminster College MO     Yes    662     553     184
# 749                      Westminster College     Yes    996     866     377
# 750    Westminster College of Salt Lake City     Yes    917     720     213
# 751                         Westmont College      No    950     713     351
# 752                       Wheaton College IL     Yes   1432     920     548
# 753                   Westminster College PA     Yes   1738    1373     417
# 754                  Wheeling Jesuit College     Yes    903     755     213
# 755                          Whitman College     Yes   1861     998     359
# 756                         Whittier College     Yes   1681    1069     344
# 757                        Whitworth College     Yes   1121     926     372
# 758                       Widener University     Yes   2139    1492     502
# 759                        Wilkes University     Yes   1631    1431     434
# 760                    Willamette University     Yes   1658    1327     395
# 761                   William Jewell College     Yes    663     547     315
# 762                 William Woods University     Yes    469     435     227
# 763                         Williams College     Yes   4186    1245     526
# 764                           Wilson College     Yes    167     130      46
# 765                          Wingate College     Yes   1239    1017     383
# 766                  Winona State University      No   3325    2047    1301
# 767                      Winthrop University      No   2320    1805     769
# 768               Wisconsin Lutheran College     Yes    152     128      75
# 769                    Wittenberg University     Yes   1979    1739     575
# 770                          Wofford College     Yes   1501     935     273
# 771          Worcester Polytechnic Institute     Yes   2768    2314     682
# 772                  Worcester State College      No   2197    1515     543
# 773                        Xavier University     Yes   1959    1805     695
# 774           Xavier University of Louisiana     Yes   2097    1915     695
# 775                          Yale University     Yes  10705    2453    1317
# 776             York College of Pennsylvania     Yes   2989    1855     691
#
#      Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate     ...       \
# 0           23         52         2885          537      7440     ...
# 1           16         29         2683         1227     12280     ...
# 2           22         50         1036           99     11250     ...
# 3           60         89          510           63     12960     ...
# 4           16         44          249          869      7560     ...
# 5           38         62          678           41     13500     ...
# 6           17         45          416          230     13290     ...
# 7           37         68         1594           32     13868     ...
# 8           30         63          973          306     15595     ...
# 9           21         44          799           78     10468     ...
# 10          37         75         1830          110     16548     ...
# 11          44         77         1707           44     17080     ...
# 12          38         64         1130          638      9690     ...
# 13          44         73         1306           28     12572     ...
# 14          23         46         1317         1235      8352     ...
# 15           9         22         1018          287      8700     ...
# 16          83         96         1593            5     19760     ...
# 17          19         40         1819          281     10100     ...
# 18          14         23         1586          326      9996     ...
# 19          24         54         4190         1512      5130     ...
# 20          25         44          712           23     15476     ...
# 21          20         63         9940         1035      6806     ...
# 22          20         51         1251          767     11208     ...
# 23          24         49        22593         7585      7434     ...
# 24          46         74          530          182      8644     ...
# 25          12         52         3602          939      3460     ...
# 26          23         59         1708          689     12000     ...
# 27          25         57        16262         1716      6300     ...
# 28          12         30         2074          726     11902     ...
# 29          36         69         1950           38     13353     ...
# ..         ...        ...          ...          ...       ...     ...
# 747          3         20         3234          941      5542     ...
# 748         20         43          665           37     10720     ...
# 749         29         58         1411           72     12065     ...
# 750         21         60          979          743      8820     ...
# 751         42         72         1276            9     14320     ...
# 752         56         84         2200           56     11480     ...
# 753         21         55         1335           30     18460     ...
# 754         15         49          971          305     10500     ...
# 755         45         77         1220           46     16670     ...
# 756         35         63         1235           30     16249     ...
# 757         43         70         1270          160     12660     ...
# 758         24         64         2186         2171     12350     ...
# 759         15         36         1803          603     11150     ...
# 760         49         80         1595          159     14800     ...
# 761         32         67         1279           75     10060     ...
# 762         17         39          851          120     10535     ...
# 763         81         96         1988           29     19629     ...
# 764         16         50          199          676     11428     ...
# 765         10         34         1207          157      7820     ...
# 766         20         45         5800          872      4200     ...
# 767         24         61         3395          670      6400     ...
# 768         17         41          282           22      9100     ...
# 769         42         68         1980          144     15948     ...
# 770         51         83         1059           34     12680     ...
# 771         49         86         2802           86     15884     ...
# 772          4         26         3089         2029      6797     ...
# 773         24         47         2849         1107     11520     ...
# 8          27.056019        80.828516           No
# 9          34.538153        85.567010           No
# 10         33.122807        82.274827           No
# 11         25.473684        71.644042           No
# 12         37.179487        66.157761           No
# 13         35.648148        85.240726           No
# 14         50.159744        63.360324           No
# 15         20.128088        76.971831           No
# 16         42.137097        23.059042          Yes
# 17         46.585903        74.671053           No
# 18         45.738636        62.300885           No
# 19         50.774613        56.525424           No
# 20         38.124054        92.706872          Yes
# 21         40.951973        63.776836           No
# 22         42.441860        83.360258           No
# 23         36.486224        80.474666           No
# 24         49.700599        47.175141          Yes
# 25         55.002892        99.711649           No
# 26         28.882353        79.625293           No
# 27         45.206891        89.970853           No
# 28         50.097466        77.492447           No
# 29         29.975875        88.238425           No
# ..               ...              ...          ...
# 747        38.372093        69.354839           No
# 748        33.273056        83.534743           No
# 749        43.533487        86.947791           No
# 750        29.583333        78.516903           No
# 751        49.228612        75.052632           No
# 752        59.565217        64.245810           No
# 753        30.371449        78.998849          Yes
# 754        28.211921        83.610188           No
# 755        35.971944        53.627082           No
# 756        32.179607        63.593099           No
# 757        40.172786        82.604817           No
# 758        33.646113        69.752221           No
# 759        30.328442        87.737584           No
# 760        29.766390        80.036188           No
# 761        57.586837        82.503771           No
# 762        52.183908        92.750533           No
# 763        42.248996        29.741997          Yes
# 764        35.384615        77.844311           No
# 765        37.659784        82.082324           No
# 766        63.556424        61.563910           No
# 767        42.603878        77.801724           No
# 768        58.593750        84.210526           No
# 769        33.064980        87.872663           No
# 770        29.197861        62.291805           No
# 771        29.472774        83.598266           No
# 772        35.841584        68.957670           No
# 773        38.504155        92.138846           No
# 774        36.292428        91.320935           No
# 775        53.689360        22.914526          Yes
# 776        37.250674        62.060890           No
#
# [777 rows x 22 columns]

# %%
dataset[dataset['Class_label'] == np.nan]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate, Enrollment_Rate, Acceptance Rate, Class_label]
# Index: []
#
# [0 rows x 22 columns]

# %%
dataset.shape
# Out:
# (777, 22)

# %%
dataset[dataset['Class_label'] == 'Yes'].shape
# Out:
# (106, 22)

# %%
'''
test=dataset.loc[(dataset['Expend']==i2[0][0])&(dataset['Enrollment_Rate']==i2[0][1])]
test['Label']
print(test)
'''
numRows, numCols = dataset.shape

# %%
TP=TN=FP=FN=0
# for kk2 in range(numRows):
#     rowdf = dataset.loc[kk2,:]
#     print(rowdf)
    
factual_data=list(dataset['Private'])
test_data=list(dataset['Class_label'])

#print(factual_data,"\n",test_data)

for x,y in zip(factual_data,test_data):
    if x==y and x=='Yes':
        TP+=1
    if x==y and x=='No':
        TN+=1
    if x!=y and x=='Yes':
        FN+=1
    if x!=y and x=='No':
        FP+=1
    
#     if dataset.loc[kk2, dataset.columns.get_loc('Private')]:#.equals(dataset.loc[kk2, dataset.columns.get_loc('Class_label')]):
#         if dataset[kk2, dataset.columns.get_loc('Private')] == 'No':
#             TN+=1
#         else:
#             TP+=1
#     else:
#         if dataset[kk2, dataset.columns.get_loc('Private')] == 'No':
#             FP+=1
#         else:
#             FN+=1

print("ACCURACY by Confusion Matrix:")
print((TP+TN)/(numRows))
print()

print("Recall:")
Recall = (TP/(TP+FN))
print(Recall)
print()

print("Precision:")
Precision = (TP/(TP+FP))
print(Precision)
print()

print("F-Measure:")
print((2*Recall*Precision)/(Recall+Precision))
print()
print("$$$$$ TN : ", TN)
print("$$$$$ FN : ", FN)

#Low recall, high precision: Shows that we miss a lot of positive examples (high FN) but those we predict as positive are indeed positive (low FP)
# Out:
# ACCURACY by Confusion Matrix:
# 0.38095238095238093
#
# Recall:
# 0.168141592920354
#
# Precision:
# 0.8962264150943396
#
# F-Measure:
# 0.2831594634873324
#
# $$$$$ TN :  201
# $$$$$ FN :  470

# %%
######## USING SKLEARN - COMPARING RESULTS WITH LIBRARY FNS./APIs #########

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
Y = dataset[['Enrollment_Rate']]
X = dataset[['Expend']]

# %%
Nc = range(1, 20)
kmeans = [KMeans(n_clusters=i) for i in Nc]
#kmeans

# %%
score = [kmeans[i].fit(Y).score(Y) for i in range(len(kmeans))]
#score

# %%
plt.scatter(Nc,score,c='red')
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
pca = PCA(n_components=1).fit(Y)
pca_d = pca.transform(Y)
pca_c = pca.transform(X)

# %%
kmeans=KMeans(n_clusters=2)
kmeansoutput=kmeans.fit(Y)
kmeansoutput
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
plt.figure('2 Cluster K-Means')
plt.scatter(pca_c[:, 0], pca_d[:, 0], c=kmeansoutput.labels_)
plt.xlabel('Dividend Yield')
plt.ylabel('Returns')
plt.title('2 Cluster K-Means')
plt.show()

# %%
######### ENTROPY CALCULATION ########## - Lower entropy, better cluster purity/validity
import math

clustersj = dataset[['Class_label']]
classi = dataset[['Private']]
count1 = 0

mij = [] #ij = YesYes, YesNo, NoYes, NoNo order
mj = [] #Yes, No order
pij = [] #ij = YesYes, YesNo, NoYes, NoNo order

mj1, mjr = clustersj[clustersj['Class_label'] == 'Yes'].shape
mj.append(mj1)
mj1, mjr = clustersj[clustersj['Class_label'] == 'No'].shape
mj.append(mj1)

mi1, mjr = classi[classi['Private'] == 'Yes'].shape
#print(mi1)

test1=dataset.loc[(dataset['Private']=='Yes')&(dataset['Class_label']=='Yes'),:]
count1, mjr = test1.shape
mij.append(count1)
test2=dataset.loc[(dataset['Private']=='Yes')&(dataset['Class_label']=='No'),:]
count2, mjr = test2.shape
mij.append(count2)
test3=dataset.loc[(dataset['Private']=='No')&(dataset['Class_label']=='Yes'),:]
count3, mjr = test3.shape
mij.append(count3)
test4=dataset.loc[(dataset['Private']=='No')&(dataset['Class_label']=='No'),:]
count4, mjr = test4.shape
mij.append(count4)

#print(mj)

#print(mij)

pij.append(float(mij[0])/float(mj[0]))
pij.append(float(mij[2])/float(mj[0]))
pij.append(float(mij[1])/float(mj[1]))
pij.append(float(mij[3])/float(mj[1]))
        
#print(pij)
#print("\n\n")

Entropy = 0.0

for i in pij:
    #print(i*(math.log(i,2)))
    Entropy += (i*(math.log(i,2))) #math.log(num, base)
Entropy = - Entropy
print("############# ---------- ###########\n")
print("ENTROPY :\n")
print(Entropy)
# Out:
# ############# ---------- ###########
#
# ENTROPY :
#
# 1.3615883824425903
